# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ptick

# %%
left = ['m400', 'm1000', 'm2200', 'm2800']
myr = [0.5702, 1.104, 1.703, 2.188]
plt.rcParams["font.size"] = 15

# %%
# plot the number of structures in 2D

plt.plot(left, [3, 3, 4, 5], marker='o', label='leaves')
plt.plot(left, [2, 2, 2, 4], marker='o', label='branches')
plt.yticks(np.arange(0, 6, 1)) 

plt.title("The number of structures in 2D")
plt.xlabel("time progress")
plt.ylabel("number")
plt.legend()

# %%
# make histgram the size of all structures in 2D

leaf_size_400 = [126.470768, 86.230069, 55.570489]
leaf_size_1000 = [47.905594, 136.051887, 40.240699]
leaf_size_2200 = [42.156923, 38.324475, 84.313846, 40.240699]
leaf_size_2800 = [643.851185, 49.821818, 51.738042, 76.648951, 45.989370]

branch_size_400 = [1191.891181, 343.004054]
branch_size_1000 = [858.468246, 967.693001]
branch_size_2200 = [845.054680, 241.444194]
branch_size_2800 = [825.892442, 76.648951, 544.207549, 312.344474]

bins = 12
range = (0, 1200)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8), sharex=True, sharey=True)
axes[0, 0].hist(leaf_size_400, bins=bins, range=range, label='leaves')
axes[0, 0].hist(branch_size_400, bins=bins, range=range, alpha=0.5, label='branches')
axes[0, 1].hist(leaf_size_1000, bins=bins, range=range, label='leaves')
axes[0, 1].hist(branch_size_1000, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 0].hist(leaf_size_2200, bins=bins, range=range, label='leaves')
axes[1, 0].hist(branch_size_2200, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 1].hist(leaf_size_2800, bins=bins, range=range, label='leaves')
axes[1, 1].hist(branch_size_2800, bins=bins, range=range, alpha=0.5, label='branches')

plt.yticks(np.arange(0, 5, 1)) 

axes[0, 0].set_title('0.57 Myr')
axes[0, 0].set_ylabel('number')
axes[0, 0].legend(fontsize=12)
axes[0, 1].set_title('1.1 Myr')
axes[0, 1].legend(fontsize=12)
axes[1, 0].set_title('1.7 Myr')
axes[1, 0].set_xlabel('size [pc$^2$]')
axes[1, 0].set_ylabel('number')
axes[1, 0].legend(fontsize=12)
axes[1, 1].set_title('2.2 Myr')
axes[1, 1].set_xlabel('size [pc$^2$]')
axes[1, 1].legend(fontsize=12)

# %%
# make histgram of the mass of all structures in 2D

leaf_mass_400 = [73370.271193, 59195.409926, 34242.341824]
leaf_mass_1000 = [25696.755630, 116010.159091, 30320.895491]
leaf_mass_2200 = [17681.274058, 31640.512221, 83040.930547, 35963.249325]
leaf_mass_2800 = [396224.998561, 28825.734398, 27920.592740, 73440.105220, 38690.143075]

branch_mass_400 = [575791.385619, 202409.555750]
branch_mass_1000 = [493971.113690, 540569.898709]
branch_mass_2200 = [502886.881742, 197254.124985]
branch_mass_2800 = [473164.767962, 52118.290098, 349546.853826, 226889.682633]

bins = 12
range = (0, 600000)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8), sharex=True, sharey=True)
axes[0, 0].hist(leaf_mass_400, bins=bins, range=range, label='leaves')
axes[0, 0].hist(branch_mass_400, bins=bins, range=range, alpha=0.5, label='branches')
axes[0, 1].hist(leaf_mass_1000, bins=bins, range=range, label='leaves')
axes[0, 1].hist(branch_mass_1000, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 0].hist(leaf_mass_2200, bins=bins, range=range, label='leaves')
axes[1, 0].hist(branch_mass_2200, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 1].hist(leaf_mass_2800, bins=bins, range=range, label='leaves')
axes[1, 1].hist(branch_mass_2800, bins=bins, range=range, alpha=0.5, label='branches')

axes[0, 0].xaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
axes[0, 0].ticklabel_format(style="sci", axis="x", scilimits=(5,5))
axes[0, 1].xaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
axes[0, 1].ticklabel_format(style="sci", axis="x", scilimits=(5,5))
axes[1, 0].xaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
axes[1, 0].ticklabel_format(style="sci", axis="x", scilimits=(5,5))
axes[1, 1].xaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
axes[1, 1].ticklabel_format(style="sci", axis="x", scilimits=(5,5))

plt.yticks(np.arange(0, 5, 1)) 

axes[0, 0].set_title('0.57 myr')
axes[0, 0].set_ylabel('number')
axes[0, 0].legend(fontsize=12)
axes[0, 1].set_title('1.1 Myr')
axes[0, 1].legend(fontsize=12)
axes[1, 0].set_title('1.7 Myr')
axes[1, 0].set_xlabel('mass [$M_☉$]')
axes[1, 0].set_ylabel('number')
axes[1, 0].legend(fontsize=12)
axes[1, 1].set_title('1.1 Myr')
axes[1, 1].set_xlabel('mass [$M_☉$]')
axes[1, 1].legend(fontsize=12)

# %%
# make histgram of virial parameter of all structures in 2D

leaf_alpha_vir_400 = [4.722276, 4.253963, 9.481851]
leaf_alpha_vir_1000 = [3.394635, 2.126267, 3.037094]
leaf_alpha_vir_2200 = [4.148533, 7.343862, 1.802149, 2.536909]
leaf_alpha_vir_2800 = [1.254208, 1.882905, 5.578453, 1.531594, 1.653504]

branch_alpha_vir_400 = [2.717164, 3.180097]
branch_alpha_vir_1000 = [1.691396, 1.933227]
branch_alpha_vir_2200 = [1.277130, 1.561242]
branch_alpha_vir_2800 = [1.165583, 5.123569, 1.238741, 1.174091]

bins = 12
range = (0, 12)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8), sharex=True, sharey=True)
axes[0, 0].hist(leaf_alpha_vir_400, bins=bins, range=range, label='leaves')
axes[0, 0].hist(branch_alpha_vir_400, bins=bins, range=range, alpha=0.5, label='branches')
axes[0, 1].hist(leaf_alpha_vir_1000, bins=bins, range=range, label='leaves')
axes[0, 1].hist(branch_alpha_vir_1000, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 0].hist(leaf_alpha_vir_2200, bins=bins, range=range, label='leaves')
axes[1, 0].hist(branch_alpha_vir_2200, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 1].hist(leaf_alpha_vir_2800, bins=bins, range=range, label='leaves')
axes[1, 1].hist(branch_alpha_vir_2800, bins=bins, range=range, alpha=0.5, label='branches')

plt.xticks(np.arange(0, 12, 2))

axes[0, 0].set_title('0.57 Myr')
axes[0, 0].set_ylabel('number')
axes[0, 0].legend(fontsize=12)
axes[0, 1].set_title('1.1 Myr')
axes[0, 1].legend(fontsize=12)
axes[1, 0].set_title('1.7 Myr')
axes[1, 0].set_xlabel('virial parameter')
axes[1, 0].set_ylabel('number')
axes[1, 0].legend(fontsize=12)
axes[1, 1].set_title('2.2 Myr')
axes[1, 1].set_xlabel('virial parameter')
axes[1, 1].legend(fontsize=12)

# %%
# plot the　size of trunk in 2D

trunk_size = [np.max(branch_size_400), np.max(branch_size_1000), np.max(branch_size_2200), np.max(branch_size_2800)]

plt.plot(myr, trunk_size, marker="o")

plt.title("size of trunk")
plt.xlabel("time [Myr]")
plt.ylabel('size [pc$^2$]')
# Out:
# Text(0, 0.5, 'size [pc$^2$]')

# %%
# plot the mass and virial mass of trunk in 2D

trunk_mass = [np.max(branch_mass_400), np.max(branch_mass_1000), np.max(branch_mass_2200), np.max(branch_mass_2800)]
fig, ax = plt.subplots()

ax.plot(myr, trunk_mass, marker="o", label='M')

ax.yaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
ax.ticklabel_format(style="sci", axis="y", scilimits=(5,5))

plt.title("mass of trunk")
plt.xlabel("time [Myr]")
plt.ylabel('mass [$M_☉$]')
# Out:
# Text(0, 0.5, 'mass [$M_☉$]')

# %%
# plot virial parameter of trunk in 2D

alpha_gvir = [np.max(branch_alpha_vir_400), np.max(branch_alpha_vir_1000), np.max(branch_alpha_vir_2200), 1.238741]

plt.plot(myr, alpha_gvir, marker="o")

plt.title("virial parameter of trunk")
plt.xlabel("time [Myr]")
plt.ylabel("virial parameter")
# Out:
# Text(0, 0.5, 'virial parameter')

# %%
# plot average of size

leaf_size_ave = [89.4237756729126, 74.73272681236267, 51.258985698223114, 173.60987305641174]
branch_size_ave = [767.447617650032, 913.0806237459183, 543.249437212944, 439.773353934288]

plt.plot(myr, leaf_size_ave, marker='o', label='leaf')
plt.plot(myr, branch_size_ave, marker='o', label='branch')

plt.title('average of size')
plt.xlabel('time [Myr]')
plt.ylabel('size [$pc^2$]')
plt.legend()

# %%
# plot average of mass

leaf_mass_ave = [55602.6743142876, 57342.603403641515, 42081.491537889924, 113020.31479875643]
branch_mass_ave = [389100.4706845317, 517270.50619937567, 350070.50336342875, 275429.89863014815]

plt.plot(myr, leaf_mass_ave, marker='o', label='leaf')
plt.plot(myr, branch_mass_ave, marker='o', label='branch')

plt.title('average of mass')
plt.xlabel('time [Myr]')
plt.ylabel('mass [$M_\odot$]')
plt.tick_params(labelsize=12)
plt.legend()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\o'
# <>:11: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\kotor\AppData\Local\Temp\ipykernel_9692\2955348128.py:11: SyntaxWarning: invalid escape sequence '\o'
#   plt.ylabel('mass [$M_\odot$]')

# %%
# plot average of vir

leaf_vir_ave = [6.152696910409017, 2.8526652161365953, 3.9578632659285335, 2.380132637301463]
branch_vir_ave = [2.9486303617387764, 1.8123111339706104, 1.419185889063007, 2.1754959439354056]

plt.plot(myr, leaf_vir_ave, marker='o', label='leaf')
plt.plot(myr, branch_vir_ave, marker='o', label='branch')

plt.title('average of vir')
plt.xlabel('time [Myr]')
plt.ylabel('virial parameter]')
plt.legend()
