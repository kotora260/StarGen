# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
myr_m4 = [0.54, 1.08, 1.63, 2.17, 2.72, 
       3.26, 3.80, 4.35, 4.89, 5.43, 
       5.98, 6.52, 7.06, 7.61, 8.15, 
       8.46, 8.73, 9.01, 9.25, 9.46, 
       9.73, 10.0, 10.3, 10.5, 10.8, 
       11, 11.3, 11.6, 11.9, 12.1, 
       12.4, 12.7, 13, 13.2, 13.5, 
       13.8, 14.0, 14.3, 14.6, 14.9, 
       15, 15.2, 15.3]
myr_m5 = [0.47, 0.81, 0.99, 1.1, 1.3, 1.4, 1.5, 1.7, 1.8, 1.9, 2.0]
myr_m6 = [0.57, 1.1, 1.7, 2.2]

for i in range(200, 8800, 200):
    filename = f'C:/users/kotor/StarGen/datasets/simdata/m4r20z1a1/results_leaves_{i}_3D.csv'
    globals()[f'm4_{i}_leaves'] = pd.read_csv(filename)
    filename = f'C:/users/kotor/StarGen/datasets/simdata/m4r20z1a1/results_branches_{i}_3D.csv'
    globals()[f'm4_{i}_branches'] = pd.read_csv(filename)
    if globals()[f'm4_{i}_branches'].empty:
       globals()[f'm4_{i}_structures'] = globals()[f'm4_{i}_leaves']
    else:
       globals()[f'm4_{i}_structures'] = pd.concat([globals()[f'm4_{i}_leaves'], globals()[f'm4_{i}_branches']], axis=0, ignore_index=True)

for i in range(200, 2400, 200):
    filename = f'C:/users/kotor/StarGen/datasets/simdata/m4r20z1a1/results_leaves_{i}_3D.csv'
    globals()[f'm5_{i}_leaves'] = pd.read_csv(filename)
    filename = f'C:/users/kotor/StarGen/datasets/simdata/m4r20z1a1/results_branches_{i}_3D.csv'
    globals()[f'm5_{i}_branches'] = pd.read_csv(filename)
    if globals()[f'm5_{i}_branches'].empty:
       globals()[f'm5_{i}_structures'] = globals()[f'm5_{i}_leaves']
    else:
       globals()[f'm5_{i}_structures'] = pd.concat([globals()[f'm5_{i}_leaves'], globals()[f'm5_{i}_branches']], axis=0, ignore_index=True)

m400_leaves = pd.read_csv('C:/users/kotor/StarGen/datasets/simdata/gradsim/ppv/results_leaves_400_3D.csv')
m400_branches = pd.read_csv('C:/users/kotor/StarGen/datasets/simdata/gradsim/ppv/results_branches_400_3D.csv')
m400_structures = pd.concat([m400_leaves, m400_branches], axis=0, ignore_index=True)
m1000_leaves = pd.read_csv('C:/users/kotor/StarGen/datasets/simdata/gradsim/ppv/results_leaves_1000_3D.csv')
m1000_branches = pd.read_csv('C:/users/kotor/StarGen/datasets/simdata/gradsim/ppv/results_branches_1000_3D.csv')
m1000_structures = pd.concat([m1000_leaves, m1000_branches], axis=0, ignore_index=True)
m2200_leaves = pd.read_csv('C:/users/kotor/StarGen/datasets/simdata/gradsim/ppv/results_leaves_2200_3D.csv')
m2200_branches = pd.read_csv('C:/users/kotor/StarGen/datasets/simdata/gradsim/ppv/results_branches_2200_3D.csv')
m2200_structures = pd.concat([m2200_leaves, m2200_branches], axis=0, ignore_index=True)
m2800_leaves = pd.read_csv('C:/users/kotor/StarGen/datasets/simdata/gradsim/ppv/results_leaves_2800_3D.csv')
m2800_branches = pd.read_csv('C:/users/kotor/StarGen/datasets/simdata/gradsim/ppv/results_branches_2800_3D.csv')
m2800_structures = pd.concat([m2800_leaves, m2800_branches], axis=0, ignore_index=True)

# %%
leaves_m4, branches_m4 = [], []
leaves_m5, branches_m5 = [], []
for i in range(200, 8800, 200):
    leaves_m4.append(globals()[f'm4_{i}_leaves'].shape[0])
    branches_m4.append(globals()[f'm4_{i}_branches'].shape[0])
for i in range(200, 2400, 200):
    leaves_m5.append(globals()[f'm5_{i}_leaves'].shape[0])
    branches_m5.append(globals()[f'm5_{i}_branches'].shape[0])

plt.plot(myr_m4, leaves_m4, marker='o', color='blue', label='leaves')
plt.plot(myr_m4, branches_m4, marker='x', color='blue', label='branches')
plt.plot(myr_m5, leaves_m5, marker='o', color='orange', label='leaves')
plt.plot(myr_m5, branches_m5, marker='x', color='orange', label='branches')
plt.yticks(np.arange(0, 5, 1))
plt.title('Number of leaves and branches')
plt.xlabel('time [Myr]')
plt.ylabel('number')
plt.legend()

# %%
trunk_size_m4, trunk_mass_m4, trunk_velocity_dispersion_m4, trunk_virial_parameter_m4 = [], [], [], []
trunk_size_m5, trunk_mass_m5, trunk_velocity_dispersion_m5, trunk_virial_parameter_m5 = [], [], [], []
for i in range(200, 8800, 200):
    trunk_index = globals()[f'm4_{i}_structures']['radius'].idxmax()
    trunk_size_m4.append(globals()[f'm4_{i}_structures']['radius'][trunk_index])
    trunk_mass_m4.append(globals()[f'm4_{i}_structures']['mass'][trunk_index])
    trunk_velocity_dispersion_m4.append(globals()[f'm4_{i}_structures']['velocity dispersion'][trunk_index])
    trunk_virial_parameter_m4.append(globals()[f'm4_{i}_structures']['virial parameter'][trunk_index])
for i in range(200, 2400, 200):
    trunk_index = globals()[f'm5_{i}_structures']['radius'].idxmax()
    trunk_size_m5.append(globals()[f'm5_{i}_structures']['radius'][trunk_index])
    trunk_mass_m5.append(globals()[f'm5_{i}_structures']['mass'][trunk_index])
    trunk_velocity_dispersion_m5.append(globals()[f'm5_{i}_structures']['velocity dispersion'][trunk_index])
    trunk_virial_parameter_m5.append(globals()[f'm5_{i}_structures']['virial parameter'][trunk_index])

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(myr_m4, trunk_size_m4, marker='o', label='mass = 1e4 $M_\odot$')
ax.plot(myr_m5, trunk_size_m5, marker='o', label='mass = 1e5 $M_\odot$')
ax.set_xlabel('time [Myr]')
ax.set_ylabel('size [pc]')
ax.legend()

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(myr_m4, trunk_mass_m4, marker='o', label='mass = 1e4 $M_\odot$')
ax.plot(myr_m5, trunk_mass_m5, marker='o', label='mass = 1e5 $M_\odot$')
ax.set_xlabel('time [Myr]')
ax.set_ylabel('mass [$M_\odot$]')
ax.legend()

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(myr_m4, trunk_velocity_dispersion_m4, marker='o', label='mass = 1e4 $M_\odot$')
ax.plot(myr_m5, trunk_velocity_dispersion_m5, marker='o', label='mass = 1e5 $M_\odot$')
ax.set_xlabel('time [Myr]')
ax.set_ylabel('velocity dispersion [km/s]')
ax.legend()

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(myr_m4, trunk_virial_parameter_m4, marker='o', label='mass = 1e4 $M_\odot$')
ax.plot(myr_m5, trunk_virial_parameter_m5, marker='o', label='mass = 1e5 $M_\odot$')
ax.set_xlabel('time [Myr]')
ax.set_ylabel('virial parameter')
ax.legend()
# Out:
# <>:17: SyntaxWarning: invalid escape sequence '\o'
# <>:18: SyntaxWarning: invalid escape sequence '\o'
# <>:24: SyntaxWarning: invalid escape sequence '\o'
# <>:25: SyntaxWarning: invalid escape sequence '\o'
# <>:27: SyntaxWarning: invalid escape sequence '\o'
# <>:31: SyntaxWarning: invalid escape sequence '\o'
# <>:32: SyntaxWarning: invalid escape sequence '\o'
# <>:38: SyntaxWarning: invalid escape sequence '\o'
# <>:39: SyntaxWarning: invalid escape sequence '\o'
# <>:17: SyntaxWarning: invalid escape sequence '\o'
# <>:18: SyntaxWarning: invalid escape sequence '\o'
# <>:24: SyntaxWarning: invalid escape sequence '\o'
# <>:25: SyntaxWarning: invalid escape sequence '\o'
# <>:27: SyntaxWarning: invalid escape sequence '\o'
# <>:31: SyntaxWarning: invalid escape sequence '\o'
# <>:32: SyntaxWarning: invalid escape sequence '\o'
# <>:38: SyntaxWarning: invalid escape sequence '\o'
# <>:39: SyntaxWarning: invalid escape sequence '\o'
# ...

# %%
for i in range(200, 8800, 200):
    trunk_index = globals()[f'm4_{i}_structures']['radius'].idxmax()
    globals()[f'inner_structure_m4_{i}'] = globals()[f'm4_{i}_structures'].drop(trunk_index)
for i in range(200, 2400, 200):
    trunk_index = globals()[f'm5_{i}_structures']['radius'].idxmax()
    globals()[f'inner_structure_m5_{i}'] = globals()[f'm4_{i}_structures'].drop(trunk_index)

inner_mean_size_m4, inner_mean_mass_m4, inner_mean_velocity_dispersion_m4, inner_mean_virial_parameter_m4 = [], [], [], []
inner_mean_size_m5, inner_mean_mass_m5, inner_mean_velocity_dispersion_m5, inner_mean_virial_parameter_m5 = [], [], [], []
for i in range(200, 8800, 200):
    inner_mean_size_m4.append(globals()[f'inner_structure_m4_{i}']['radius'].mean())
    inner_mean_mass_m4.append(globals()[f'inner_structure_m4_{i}']['mass'].mean())
    inner_mean_velocity_dispersion_m4.append(globals()[f'inner_structure_m4_{i}']['velocity dispersion'].mean())
    inner_mean_virial_parameter_m4.append(globals()[f'inner_structure_m4_{i}']['virial parameter'].mean())
for i in range(200, 2400, 200):
    inner_mean_size_m5.append(globals()[f'inner_structure_m5_{i}']['radius'].mean())
    inner_mean_mass_m5.append(globals()[f'inner_structure_m5_{i}']['mass'].mean())
    inner_mean_velocity_dispersion_m5.append(globals()[f'inner_structure_m5_{i}']['velocity dispersion'].mean())
    inner_mean_virial_parameter_m5.append(globals()[f'inner_structure_m5_{i}']['virial parameter'].mean())

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(myr_m4, inner_mean_size_m4, marker='o', label='mass = 1e4 $M_\odot$')
ax.plot(myr_m5, inner_mean_size_m5, marker='o', label='mass = 1e5 $M_\odot$')
ax.set_xlabel('time [Myr]')
ax.set_ylabel('size [pc]')
ax.legend()

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(myr_m4, inner_mean_mass_m4, marker='o', label='mass = 1e4 $M_\odot$')
ax.plot(myr_m5, inner_mean_mass_m5, marker='o', label='mass = 1e5 $M_\odot$')
ax.set_xlabel('time [Myr]')
ax.set_ylabel('mass [$M_\odot$]')
ax.legend()

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(myr_m4, inner_mean_velocity_dispersion_m4, marker='o', label='mass = 1e4 $M_\odot$')
ax.plot(myr_m5, inner_mean_velocity_dispersion_m5, marker='o', label='mass = 1e5 $M_\odot$')
ax.set_xlabel('time [Myr]')
ax.set_ylabel('velocity dispersion [km/s]')
ax.legend()

fig, ax = plt.subplots(figsize=(8, 6))
ax.plot(myr_m4, inner_mean_virial_parameter_m4, marker='o', label='mass = 1e4 $M_\odot$')
ax.plot(myr_m5, inner_mean_virial_parameter_m5, marker='o', label='mass = 1e5 $M_\odot$')
ax.set_xlabel('time [Myr]')
ax.set_ylabel('virial parameter')
ax.legend()
# Out:
# <>:22: SyntaxWarning: invalid escape sequence '\o'
# <>:23: SyntaxWarning: invalid escape sequence '\o'
# <>:29: SyntaxWarning: invalid escape sequence '\o'
# <>:30: SyntaxWarning: invalid escape sequence '\o'
# <>:32: SyntaxWarning: invalid escape sequence '\o'
# <>:36: SyntaxWarning: invalid escape sequence '\o'
# <>:37: SyntaxWarning: invalid escape sequence '\o'
# <>:43: SyntaxWarning: invalid escape sequence '\o'
# <>:44: SyntaxWarning: invalid escape sequence '\o'
# <>:22: SyntaxWarning: invalid escape sequence '\o'
# <>:23: SyntaxWarning: invalid escape sequence '\o'
# <>:29: SyntaxWarning: invalid escape sequence '\o'
# <>:30: SyntaxWarning: invalid escape sequence '\o'
# <>:32: SyntaxWarning: invalid escape sequence '\o'
# <>:36: SyntaxWarning: invalid escape sequence '\o'
# <>:37: SyntaxWarning: invalid escape sequence '\o'
# <>:43: SyntaxWarning: invalid escape sequence '\o'
# <>:44: SyntaxWarning: invalid escape sequence '\o'
# ...
