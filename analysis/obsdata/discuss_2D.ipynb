# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.axes_grid1.inset_locator import InsetPosition
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objects as go
from plotly import offline
import pandas as pd

# %%
W43_leaves = pd.read_csv('C:/Users/kotor/StarGen/datasets/obsdata/W43/13CO_100x100_leaves.csv')
W43_trunk = pd.read_csv('C:/Users/kotor/StarGen/datasets/obsdata/W43/13CO_100x100_trunk.csv')
W51_leaves = pd.read_csv('C:/Users/kotor/StarGen/datasets/obsdata/W51/13CO_100x100_leaves.csv')
W51_trunk = pd.read_csv('C:/Users/kotor/StarGen/datasets/obsdata/W51/13CO_100x100_trunk.csv')
M16_leaves = pd.read_csv('C:/Users/kotor/StarGen/datasets/obsdata/M16/13CO_30x30_leaves.csv')
M16_trunk = pd.read_csv('C:/Users/kotor/StarGen/datasets/obsdata/M16/13CO_30x30_trunk.csv')
M17_leaves = pd.read_csv('C:/Users/kotor/StarGen/datasets/obsdata/M17/13CO_21x21_leaves.csv')
M17_trunk = pd.read_csv('C:/Users/kotor/StarGen/datasets/obsdata/M17/13CO_21x21_trunk.csv')

sim_400_leaves = pd.read_csv('C:/Users/kotor/StarGen/datasets/simdata/results_leaves_400.csv')
sim_400_branches = pd.read_csv('C:/Users/kotor/StarGen/datasets/simdata/results_branches_400.csv')
sim_1000_leaves = pd.read_csv('C:/Users/kotor/StarGen/datasets/simdata/results_leaves_1000.csv')
sim_1000_branches = pd.read_csv('C:/Users/kotor/StarGen/datasets/simdata/results_branches_1000.csv')
sim_2200_leaves = pd.read_csv('C:/Users/kotor/StarGen/datasets/simdata/results_leaves_2200.csv')
sim_2200_branches = pd.read_csv('C:/Users/kotor/StarGen/datasets/simdata/results_branches_2200.csv')
sim_2800_leaves = pd.read_csv('C:/Users/kotor/StarGen/datasets/simdata/results_leaves_2800.csv')
sim_2800_branches = pd.read_csv('C:/Users/kotor/StarGen/datasets/simdata/results_branches_2800.csv')

# %%
fig = plt.figure(figsize=(20,20))
gs = fig.add_gridspec(4, 4)

bins = 20

ax1 = fig.add_subplot(gs[0, 0])
ax1.hist(W43_leaves['radius'], bins=bins, histtype='step', label='W43')
ax1.hist(W51_leaves['radius'], bins=bins, histtype='step', label='W51')
ax1.hist(M16_leaves['radius'], bins=bins, histtype='step', label='M16')
ax1.hist(M17_leaves['radius'], bins=bins, histtype='step', label='M17')
ax1.hist(sim_400_leaves['radius'], bins=bins, alpha=0.3, label='simulation 0.57 Myr')
ax1.hist(sim_1000_leaves['radius'], bins=bins, alpha=0.3, label='simulation 1.1 Myr')
        
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('radius [pc]')
ax1.set_ylabel('count')
ax1.legend(bbox_to_anchor=(0, -0.2), loc='upper left')

ax2 = fig.add_subplot(gs[0, 1])
ax2.scatter(W43_leaves['radius'], W43_leaves['mass'])
ax2.scatter(W51_leaves['radius'], W51_leaves['mass'])
ax2.scatter(M16_leaves['radius'], M16_leaves['mass'])
ax2.scatter(M17_leaves['radius'], M17_leaves['mass'])
ax2.scatter(sim_400_leaves['radius'], sim_400_leaves['mass'], marker='x')
ax2.scatter(sim_1000_leaves['radius'], sim_1000_leaves['mass'], marker='x')
ax2.scatter(sim_2200_leaves['radius'], sim_2200_leaves['mass'], marker='x')
ax2.scatter(sim_2800_leaves['radius'], sim_2800_leaves['mass'], marker='x')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('radius [pc]')
ax2.set_ylabel('mass [$M_\odot$]')

ax3 = fig.add_subplot(gs[0, 2])
ax3.scatter(W43_leaves['radius'], W43_leaves['velocity dispersion'])
ax3.scatter(W51_leaves['radius'], W51_leaves['velocity dispersion'])
ax3.scatter(M16_leaves['radius'], M16_leaves['velocity dispersion'])
ax3.scatter(M17_leaves['radius'], M17_leaves['velocity dispersion'])
ax3.scatter(sim_400_leaves['radius'], sim_400_leaves['velocity dispersion'], marker='x')
ax3.scatter(sim_1000_leaves['radius'], sim_1000_leaves['velocity dispersion'], marker='x')
ax3.scatter(sim_2200_leaves['radius'], sim_2200_leaves['velocity dispersion'], marker='x')
ax3.scatter(sim_2800_leaves['radius'], sim_2800_leaves['velocity dispersion'], marker='x')
ax3.set_xscale('log')
ax3.set_yscale('log')
ax3.set_xlabel('radius [pc]')
ax3.set_ylabel('velocity dispersion [km/s]')

ax4 = fig.add_subplot(gs[0, 3])
ax4.scatter(W43_leaves['radius'], W43_leaves['virial parameter'])
ax4.scatter(W51_leaves['radius'], W51_leaves['virial parameter'])
ax4.scatter(M16_leaves['radius'], M16_leaves['virial parameter'])
ax4.scatter(M17_leaves['radius'], M17_leaves['virial parameter'])
ax4.scatter(sim_400_leaves['radius'], sim_400_leaves['virial parameter'], marker='x')
ax4.scatter(sim_1000_leaves['radius'], sim_1000_leaves['virial parameter'], marker='x')
ax4.scatter(sim_2200_leaves['radius'], sim_2200_leaves['virial parameter'], marker='x')
ax4.scatter(sim_2800_leaves['radius'], sim_2800_leaves['virial parameter'], marker='x')
ax4.set_xscale('log')
ax4.set_yscale('log')
ax4.set_xlabel('radius [pc]')
ax4.set_ylabel('virial parameter')

ax6 = fig.add_subplot(gs[1, 1])
ax6.hist(W43_leaves['mass'], bins=bins, histtype='step')
ax6.hist(W51_leaves['mass'], bins=bins, histtype='step')
ax6.hist(M16_leaves['mass'], bins=bins, histtype='step')
ax6.hist(M17_leaves['mass'], bins=bins, histtype='step')
ax6.hist(sim_400_leaves['mass'], bins=bins, histtype='step')
ax6.hist(sim_1000_leaves['mass'], bins=bins, histtype='step')
ax6.hist(sim_2200_leaves['mass'], bins=bins, histtype='step')
ax6.hist(sim_2800_leaves['mass'], bins=bins, histtype='step')
ax6.set_xscale('log')
ax6.set_yscale('log')
ax6.set_xlabel('mass [$M_\odot$]')
ax6.set_ylabel('count')

ax7 = fig.add_subplot(gs[1, 2])
ax7.scatter(W43_leaves['mass'], W43_leaves['velocity dispersion'], label='W43')
ax7.scatter(W51_leaves['mass'], W51_leaves['velocity dispersion'], label='W51')
ax7.scatter(M16_leaves['mass'], M16_leaves['velocity dispersion'], label='M16')
ax7.scatter(M17_leaves['mass'], M17_leaves['velocity dispersion'], label='M17')
ax7.scatter(sim_400_leaves['mass'], sim_400_leaves['velocity dispersion'], marker='x', label='simulation 0.57 Myr')
ax7.scatter(sim_1000_leaves['mass'], sim_1000_leaves['velocity dispersion'], marker='x', label='simulation 1.1 Myr')
ax7.scatter(sim_2200_leaves['mass'], sim_2200_leaves['velocity dispersion'], marker='x', label='simulation 1.7 Myr')
ax7.scatter(sim_2800_leaves['mass'], sim_2800_leaves['velocity dispersion'], marker='x', label='simulation 2.2 Myr')
ax7.set_xscale('log')
ax7.set_yscale('log')
ax7.set_xlabel('mass [$M_\odot$]')
ax7.set_ylabel('velocity dispersion [km/s]')
ax7.legend(bbox_to_anchor=(-2.4, 0.4), loc='upper left')

ax8 = fig.add_subplot(gs[1, 3])
ax8.scatter(W43_leaves['mass'], W43_leaves['virial parameter'])
ax8.scatter(W51_leaves['mass'], W51_leaves['virial parameter'])
ax8.scatter(M16_leaves['mass'], M16_leaves['virial parameter'])
ax8.scatter(M17_leaves['mass'], M17_leaves['virial parameter'])
ax8.scatter(sim_400_leaves['mass'], sim_400_leaves['virial parameter'], marker='x')
ax8.scatter(sim_1000_leaves['mass'], sim_1000_leaves['virial parameter'], marker='x')
ax8.scatter(sim_2200_leaves['mass'], sim_2200_leaves['virial parameter'], marker='x')
ax8.scatter(sim_2800_leaves['mass'], sim_2800_leaves['virial parameter'], marker='x')
ax8.set_xscale('log')
ax8.set_yscale('log')
ax8.set_xlabel('mass [$M_\odot$]')
ax8.set_ylabel('virial parameter')

ax11 = fig.add_subplot(gs[2, 2])
ax11.hist(W43_leaves['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(W51_leaves['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(M16_leaves['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(M17_leaves['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(sim_400_leaves['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(sim_1000_leaves['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(sim_2200_leaves['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(sim_2800_leaves['velocity dispersion'], bins=bins, histtype='step')
ax11.set_xscale('log')
ax11.set_yscale('log')
ax11.set_xlabel('velocity dispersion [km/s]')
ax11.set_ylabel('count')

ax12 = fig.add_subplot(gs[2, 3])
ax12.scatter(W43_leaves['velocity dispersion'], W43_leaves['virial parameter'])
ax12.scatter(W51_leaves['velocity dispersion'], W51_leaves['virial parameter'])
ax12.scatter(M16_leaves['velocity dispersion'], M16_leaves['virial parameter'])
ax12.scatter(M17_leaves['velocity dispersion'], M17_leaves['virial parameter'])
ax12.scatter(sim_400_leaves['velocity dispersion'], sim_400_leaves['virial parameter'], marker='x')
ax12.scatter(sim_1000_leaves['velocity dispersion'], sim_1000_leaves['virial parameter'], marker='x')
ax12.scatter(sim_2200_leaves['velocity dispersion'], sim_2200_leaves['virial parameter'], marker='x')
ax12.scatter(sim_2800_leaves['velocity dispersion'], sim_2800_leaves['virial parameter'], marker='x')
ax12.set_xscale('log')
ax12.set_yscale('log')
ax12.set_xlabel('velocity dispersion [km/s]')
ax12.set_ylabel('virial parameter')

ax16 = fig.add_subplot(gs[3, 3])
ax16.hist(W43_leaves['virial parameter'], bins=bins, histtype='step')
ax16.hist(W51_leaves['virial parameter'], bins=bins, histtype='step')
ax16.hist(M16_leaves['virial parameter'], bins=bins, histtype='step')
ax16.hist(M17_leaves['virial parameter'], bins=bins, histtype='step')
ax16.hist(sim_400_leaves['virial parameter'], bins=bins, histtype='step')
ax16.hist(sim_1000_leaves['virial parameter'], bins=bins, histtype='step')
ax16.hist(sim_2200_leaves['virial parameter'], bins=bins, histtype='step')
ax16.hist(sim_2800_leaves['virial parameter'], bins=bins, histtype='step')
ax16.set_xscale('log')
ax16.set_yscale('log')
ax16.set_xlabel('virial parameter')
ax16.set_ylabel('count')

plt.show()
# Out:
# <>:32: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:73: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:87: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:102: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:32: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:73: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:87: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:102: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# C:\Users\kotor\AppData\Local\Temp\ipykernel_15432\1449188292.py:32: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# C:\Users\kotor\AppData\Local\Temp\ipykernel_15432\1449188292.py:73: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# C:\Users\kotor\AppData\Local\Temp\ipykernel_15432\1449188292.py:87: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# C:\Users\kotor\AppData\Local\Temp\ipykernel_15432\1449188292.py:102: SyntaxWarning:
#
# invalid escape sequence '\o'

# %%
fig = plt.figure(figsize=(20,20))
gs = fig.add_gridspec(4, 4)

bins = 20

ax1 = fig.add_subplot(gs[0, 0])
ax1.hist(W43_trunk['radius'], bins=bins, histtype='step', label='W43')
ax1.hist(W51_trunk['radius'], bins=bins, histtype='step', label='W51')
ax1.hist(M16_trunk['radius'], bins=bins, histtype='step', label='M16')
ax1.hist(M17_trunk['radius'], bins=bins, histtype='step', label='M17')
ax1.hist(sim_400_branches['radius'], bins=bins, histtype='step', label='simulation 0.57 Myr')
ax1.hist(sim_1000_branches['radius'], bins=bins, histtype='step', label='simulation 1.1 Myr')
ax1.hist(sim_2200_branches['radius'], bins=bins, histtype='step', label='simulation 1.7 Myr')
ax1.hist(sim_2800_branches['radius'], bins=bins, histtype='step', label='simulation 2.2 Myr')
ax1.set_xscale('log')
ax1.set_yscale('log')
ax1.set_xlabel('radius [pc]')
ax1.set_ylabel('count')
ax1.legend(bbox_to_anchor=(0, -0.2), loc='upper left')

ax2 = fig.add_subplot(gs[0, 1])
ax2.scatter(W43_trunk['radius'], W43_trunk['mass'])
ax2.scatter(W51_trunk['radius'], W51_trunk['mass'])
ax2.scatter(M16_trunk['radius'], M16_trunk['mass'])
ax2.scatter(M17_trunk['radius'], M17_trunk['mass'])
ax2.scatter(sim_400_branches['radius'], sim_400_branches['mass'], marker='x')
ax2.scatter(sim_1000_branches['radius'], sim_1000_branches['mass'], marker='x')
ax2.scatter(sim_2200_branches['radius'], sim_2200_branches['mass'], marker='x')
ax2.scatter(sim_2800_branches['radius'], sim_2800_branches['mass'], marker='x')
ax2.set_xscale('log')
ax2.set_yscale('log')
ax2.set_xlabel('radius [pc]')
ax2.set_ylabel('mass [$M_\odot$]')

ax3 = fig.add_subplot(gs[0, 2])
ax3.scatter(W43_trunk['radius'], W43_trunk['velocity dispersion'])
ax3.scatter(W51_trunk['radius'], W51_trunk['velocity dispersion'])
ax3.scatter(M16_trunk['radius'], M16_trunk['velocity dispersion'])
ax3.scatter(M17_trunk['radius'], M17_trunk['velocity dispersion'])
ax3.scatter(sim_400_branches['radius'], sim_400_branches['velocity dispersion'], marker='x')
ax3.scatter(sim_1000_branches['radius'], sim_1000_branches['velocity dispersion'], marker='x')
ax3.scatter(sim_2200_branches['radius'], sim_2200_branches['velocity dispersion'], marker='x')
ax3.scatter(sim_2800_branches['radius'], sim_2800_branches['velocity dispersion'], marker='x')
ax3.set_xscale('log')
ax3.set_yscale('log')
ax3.set_xlabel('radius [pc]')
ax3.set_ylabel('velocity dispersion [km/s]')

ax4 = fig.add_subplot(gs[0, 3])
ax4.scatter(W43_trunk['radius'], W43_trunk['virial parameter'])
ax4.scatter(W51_trunk['radius'], W51_trunk['virial parameter'])
ax4.scatter(M16_trunk['radius'], M16_trunk['virial parameter'])
ax4.scatter(M17_trunk['radius'], M17_trunk['virial parameter'])
ax4.scatter(sim_400_branches['radius'], sim_400_branches['virial parameter'], marker='x')
ax4.scatter(sim_1000_branches['radius'], sim_1000_branches['virial parameter'], marker='x')
ax4.scatter(sim_2200_branches['radius'], sim_2200_branches['virial parameter'], marker='x')
ax4.scatter(sim_2800_branches['radius'], sim_2800_branches['virial parameter'], marker='x')
ax4.set_xscale('log')
ax4.set_yscale('log')
ax4.set_xlabel('radius [pc]')
ax4.set_ylabel('virial parameter')

ax6 = fig.add_subplot(gs[1, 1])
ax6.hist(W43_trunk['mass'], bins=bins, histtype='step')
ax6.hist(W51_trunk['mass'], bins=bins, histtype='step')
ax6.hist(M16_trunk['mass'], bins=bins, histtype='step')
ax6.hist(M17_trunk['mass'], bins=bins, histtype='step')
ax6.hist(sim_400_branches['mass'], bins=bins, histtype='step')
ax6.hist(sim_1000_branches['mass'], bins=bins, histtype='step')
ax6.hist(sim_2200_branches['mass'], bins=bins, histtype='step')
ax6.hist(sim_2800_branches['mass'], bins=bins, histtype='step')
ax6.set_xscale('log')
ax6.set_yscale('log')
ax6.set_xlabel('mass [$M_\odot$]')
ax6.set_ylabel('count')

ax7 = fig.add_subplot(gs[1, 2])
ax7.scatter(W43_trunk['mass'], W43_trunk['velocity dispersion'], label='W43')
ax7.scatter(W51_trunk['mass'], W51_trunk['velocity dispersion'], label='W51')
ax7.scatter(M16_trunk['mass'], M16_trunk['velocity dispersion'], label='M16')
ax7.scatter(M17_trunk['mass'], M17_trunk['velocity dispersion'], label='M17')
ax7.scatter(sim_400_branches['mass'], sim_400_branches['velocity dispersion'], marker='x', label='simulation 0.57 Myr')
ax7.scatter(sim_1000_branches['mass'], sim_1000_branches['velocity dispersion'], marker='x', label='simulation 1.1 Myr')
ax7.scatter(sim_2200_branches['mass'], sim_2200_branches['velocity dispersion'], marker='x', label='simulation 1.7 Myr')
ax7.scatter(sim_2800_branches['mass'], sim_2800_branches['velocity dispersion'], marker='x', label='simulation 2.2 Myr')
ax7.set_xscale('log')
ax7.set_yscale('log')
ax7.set_xlabel('mass [$M_\odot$]')
ax7.set_ylabel('velocity dispersion [km/s]')
ax7.legend(bbox_to_anchor=(-2.4, 0.4), loc='upper left')

ax8 = fig.add_subplot(gs[1, 3])
ax8.scatter(W43_trunk['mass'], W43_trunk['virial parameter'])
ax8.scatter(W51_trunk['mass'], W51_trunk['virial parameter'])
ax8.scatter(M16_trunk['mass'], M16_trunk['virial parameter'])
ax8.scatter(M17_trunk['mass'], M17_trunk['virial parameter'])
ax8.scatter(sim_400_branches['mass'], sim_400_branches['virial parameter'], marker='x')
ax8.scatter(sim_1000_branches['mass'], sim_1000_branches['virial parameter'], marker='x')
ax8.scatter(sim_2200_branches['mass'], sim_2200_branches['virial parameter'], marker='x')
ax8.scatter(sim_2800_branches['mass'], sim_2800_branches['virial parameter'], marker='x')
ax8.set_xscale('log')
ax8.set_yscale('log')
ax8.set_xlabel('mass [$M_\odot$]')
ax8.set_ylabel('virial parameter')

ax11 = fig.add_subplot(gs[2, 2])
ax11.hist(W43_trunk['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(W51_trunk['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(M16_trunk['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(M17_trunk['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(sim_400_branches['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(sim_1000_branches['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(sim_2200_branches['velocity dispersion'], bins=bins, histtype='step')
ax11.hist(sim_2800_branches['velocity dispersion'], bins=bins, histtype='step')
ax11.set_xscale('log')
ax11.set_yscale('log')
ax11.set_xlabel('velocity dispersion [km/s]')
ax11.set_ylabel('count')

ax12 = fig.add_subplot(gs[2, 3])
ax12.scatter(W43_trunk['velocity dispersion'], W43_trunk['virial parameter'])
ax12.scatter(W51_trunk['velocity dispersion'], W51_trunk['virial parameter'])
ax12.scatter(M16_trunk['velocity dispersion'], M16_trunk['virial parameter'])
ax12.scatter(M17_trunk['velocity dispersion'], M17_trunk['virial parameter'])
ax12.scatter(sim_400_branches['velocity dispersion'], sim_400_branches['virial parameter'], marker='x')
ax12.scatter(sim_1000_branches['velocity dispersion'], sim_1000_branches['virial parameter'], marker='x')
ax12.scatter(sim_2200_branches['velocity dispersion'], sim_2200_branches['virial parameter'], marker='x')
ax12.scatter(sim_2800_branches['velocity dispersion'], sim_2800_branches['virial parameter'], marker='x')
ax12.set_xscale('log')
ax12.set_yscale('log')
ax12.set_xlabel('velocity dispersion [km/s]')
ax12.set_ylabel('virial parameter')

ax16 = fig.add_subplot(gs[3, 3])
ax16.hist(W43_trunk['virial parameter'], bins=bins, histtype='step')
ax16.hist(W51_trunk['virial parameter'], bins=bins, histtype='step')
ax16.hist(M16_trunk['virial parameter'], bins=bins, histtype='step')
ax16.hist(M17_trunk['virial parameter'], bins=bins, histtype='step')
ax16.hist(sim_400_branches['virial parameter'], bins=bins, histtype='step')
ax16.hist(sim_1000_branches['virial parameter'], bins=bins, histtype='step')
ax16.hist(sim_2200_branches['virial parameter'], bins=bins, histtype='step')
ax16.hist(sim_2800_branches['virial parameter'], bins=bins, histtype='step')
ax16.set_xscale('log')
ax16.set_yscale('log')
ax16.set_xlabel('virial parameter')
ax16.set_ylabel('count')

plt.show()
# Out:
# <>:33: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:74: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:88: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:103: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:33: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:74: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:88: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# <>:103: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# C:\Users\kotor\AppData\Local\Temp\ipykernel_12900\144404862.py:33: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# C:\Users\kotor\AppData\Local\Temp\ipykernel_12900\144404862.py:74: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# C:\Users\kotor\AppData\Local\Temp\ipykernel_12900\144404862.py:88: SyntaxWarning:
#
# invalid escape sequence '\o'
#
# C:\Users\kotor\AppData\Local\Temp\ipykernel_12900\144404862.py:103: SyntaxWarning:
#
# invalid escape sequence '\o'
# ...

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=W43_leaves['radius'], y=W43_leaves['mass'], z=W43_leaves['velocity dispersion'], 
                           mode='markers', marker=dict(size=3, symbol='circle'), name='W43 leaves'))
fig.add_trace(go.Scatter3d(x=W51_leaves['radius'], y=W51_leaves['mass'], z=W51_leaves['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W51 leaves'))
fig.add_trace(go.Scatter3d(x=M16_leaves['radius'], y=M16_leaves['mass'], z=M16_leaves['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M16 leaves'))
fig.add_trace(go.Scatter3d(x=M17_leaves['radius'], y=M17_leaves['mass'], z=M17_leaves['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M17 leaves'))
fig.add_trace(go.Scatter3d(x=sim_400_leaves['radius'], y=sim_400_leaves['mass'], z=sim_400_leaves['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 0.57 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_1000_leaves['radius'], y=sim_1000_leaves['mass'], z=sim_1000_leaves['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.1 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_2200_leaves['radius'], y=sim_2200_leaves['mass'], z=sim_2200_leaves['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.7 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_2800_leaves['radius'], y=sim_2800_leaves['mass'], z=sim_2800_leaves['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 2.2 Myr leaves'))
fig.update_layout(scene=dict
                  (xaxis=dict(title='radius [pc]', type='log'), 
                   yaxis=dict(title='mass [M_solar]', type='log'), 
                   zaxis=dict(title='velocity dispersion [km/s]', type='log'), 
                   aspectmode='cube'))
offline.plot(fig)
# Out:
# 'temp-plot.html'

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=W43_trunk['radius'], y=W43_trunk['mass'], z=W43_trunk['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W43 trunk'))
fig.add_trace(go.Scatter3d(x=W51_trunk['radius'], y=W51_trunk['mass'], z=W51_trunk['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W51 trunk'))
fig.add_trace(go.Scatter3d(x=M16_trunk['radius'], y=M16_trunk['mass'], z=M16_trunk['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M16 trunk'))
fig.add_trace(go.Scatter3d(x=M17_trunk['radius'], y=M17_trunk['mass'], z=M17_trunk['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M17 trunk'))
fig.add_trace(go.Scatter3d(x=sim_400_branches['radius'], y=sim_400_branches['mass'], z=sim_400_branches['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 0.57 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_1000_branches['radius'], y=sim_1000_branches['mass'], z=sim_1000_branches['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.1 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_2200_branches['radius'], y=sim_2200_branches['mass'], z=sim_2200_branches['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.7 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_2800_branches['radius'], y=sim_2800_branches['mass'], z=sim_2800_branches['velocity dispersion'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 2.2 Myr branches'))
fig.update_layout(scene=dict
                    (xaxis=dict(title='radius [pc]', type='log'), 
                     yaxis=dict(title='mass [M_solar]', type='log'), 
                     zaxis=dict(title='velocity dispersion [km/s]', type='log'), 
                     aspectmode='cube'))
offline.plot(fig)
# Out:
# 'temp-plot.html'

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=W43_leaves['radius'], y=W43_leaves['mass'], z=W43_leaves['virial parameter'], 
                           mode='markers', marker=dict(size=3, symbol='circle'), name='W43 leaves'))
fig.add_trace(go.Scatter3d(x=W51_leaves['radius'], y=W51_leaves['mass'], z=W51_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W51 leaves'))
fig.add_trace(go.Scatter3d(x=M16_leaves['radius'], y=M16_leaves['mass'], z=M16_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M16 leaves'))
fig.add_trace(go.Scatter3d(x=M17_leaves['radius'], y=M17_leaves['mass'], z=M17_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M17 leaves'))
fig.add_trace(go.Scatter3d(x=sim_400_leaves['radius'], y=sim_400_leaves['mass'], z=sim_400_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 0.57 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_1000_leaves['radius'], y=sim_1000_leaves['mass'], z=sim_1000_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.1 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_2200_leaves['radius'], y=sim_2200_leaves['mass'], z=sim_2200_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.7 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_2800_leaves['radius'], y=sim_2800_leaves['mass'], z=sim_2800_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 2.2 Myr leaves'))
fig.update_layout(scene=dict
                    (xaxis=dict(title='radius [pc]', type='log'), 
                     yaxis=dict(title='mass [M_solar]', type='log'), 
                     zaxis=dict(title='virial parameter', type='log'), 
                     aspectmode='cube'))
offline.plot(fig)
# Out:
# 'temp-plot.html'

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=W43_trunk['radius'], y=W43_trunk['mass'], z=W43_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W43 trunk'))
fig.add_trace(go.Scatter3d(x=W51_trunk['radius'], y=W51_trunk['mass'], z=W51_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W51 trunk'))
fig.add_trace(go.Scatter3d(x=M16_trunk['radius'], y=M16_trunk['mass'], z=M16_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M16 trunk'))
fig.add_trace(go.Scatter3d(x=M17_trunk['radius'], y=M17_trunk['mass'], z=M17_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M17 trunk'))
fig.add_trace(go.Scatter3d(x=sim_400_branches['radius'], y=sim_400_branches['mass'], z=sim_400_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 0.57 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_1000_branches['radius'], y=sim_1000_branches['mass'], z=sim_1000_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.1 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_2200_branches['radius'], y=sim_2200_branches['mass'], z=sim_2200_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.7 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_2800_branches['radius'], y=sim_2800_branches['mass'], z=sim_2800_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 2.2 Myr branches'))
fig.update_layout(scene=dict
                    (xaxis=dict(title='radius [pc]', type='log'), 
                     yaxis=dict(title='mass [M_solar]', type='log'), 
                     zaxis=dict(title='virial parameter', type='log'), 
                     aspectmode='cube'))
offline.plot(fig)
# Out:
# 'temp-plot.html'

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=W43_leaves['radius'], y=W43_leaves['velocity dispersion'], z=W43_leaves['virial parameter'], 
                           mode='markers', marker=dict(size=3, symbol='circle'), name='W43 leaves'))
fig.add_trace(go.Scatter3d(x=W51_leaves['radius'], y=W51_leaves['velocity dispersion'], z=W51_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W51 leaves'))
fig.add_trace(go.Scatter3d(x=M16_leaves['radius'], y=M16_leaves['velocity dispersion'], z=M16_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M16 leaves'))
fig.add_trace(go.Scatter3d(x=M17_leaves['radius'], y=M17_leaves['velocity dispersion'], z=M17_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M17 leaves'))
fig.add_trace(go.Scatter3d(x=sim_400_leaves['radius'], y=sim_400_leaves['velocity dispersion'], z=sim_400_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 0.57 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_1000_leaves['radius'], y=sim_1000_leaves['velocity dispersion'], z=sim_1000_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.1 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_2200_leaves['radius'], y=sim_2200_leaves['velocity dispersion'], z=sim_2200_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.7 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_2800_leaves['radius'], y=sim_2800_leaves['velocity dispersion'], z=sim_2800_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 2.2 Myr leaves'))
fig.add_trace(go.Surface(x=np.logspace(-1, 2, 100), y=np.logspace(0, 2, 100), z=np.ones((100, 100)), 
                         opacity=0.5, name='virial equilibrium'))
fig.update_layout(scene=dict
                  (xaxis=dict(title='radius [pc]', type='log'), 
                   yaxis=dict(title='velocity dispersion [km/s]', type='log'), 
                   zaxis=dict(title='virial parameter', type='log'), 
                   aspectmode='cube'))
offline.plot(fig)
# Out:
# 'temp-plot.html'

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=W43_trunk['radius'], y=W43_trunk['velocity dispersion'], z=W43_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W43 trunk'))
fig.add_trace(go.Scatter3d(x=W51_trunk['radius'], y=W51_trunk['velocity dispersion'], z=W51_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W51 trunk'))
fig.add_trace(go.Scatter3d(x=M16_trunk['radius'], y=M16_trunk['velocity dispersion'], z=M16_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M16 trunk'))
fig.add_trace(go.Scatter3d(x=M17_trunk['radius'], y=M17_trunk['velocity dispersion'], z=M17_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M17 trunk'))
fig.add_trace(go.Scatter3d(x=sim_400_branches['radius'], y=sim_400_branches['velocity dispersion'], z=sim_400_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 0.57 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_1000_branches['radius'], y=sim_1000_branches['velocity dispersion'], z=sim_1000_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.1 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_2200_branches['radius'], y=sim_2200_branches['velocity dispersion'], z=sim_2200_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.7 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_2800_branches['radius'], y=sim_2800_branches['velocity dispersion'], z=sim_2800_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 2.2 Myr branches'))
fig.add_trace(go.Surface(x=np.logspace(-1, 2, 100), y=np.logspace(0, 2, 100), z=np.ones((100, 100)),
                            opacity=0.5, name='virial equilibrium'))
fig.update_layout(scene=dict
                    (xaxis=dict(title='radius [pc]', type='log'), 
                     yaxis=dict(title='velocity dispersion [km/s]', type='log'), 
                     zaxis=dict(title='virial parameter', type='log'), 
                     aspectmode='cube'))
offline.plot(fig)
# Out:
# 'temp-plot.html'

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=W43_leaves['mass'], y=W43_leaves['velocity dispersion'], z=W43_leaves['virial parameter'], 
                           mode='markers', marker=dict(size=3, symbol='circle'), name='W43 leaves'))
fig.add_trace(go.Scatter3d(x=W51_leaves['mass'], y=W51_leaves['velocity dispersion'], z=W51_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W51 leaves'))
fig.add_trace(go.Scatter3d(x=M16_leaves['mass'], y=M16_leaves['velocity dispersion'], z=M16_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M16 leaves'))
fig.add_trace(go.Scatter3d(x=M17_leaves['mass'], y=M17_leaves['velocity dispersion'], z=M17_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M17 leaves'))
fig.add_trace(go.Scatter3d(x=sim_400_leaves['mass'], y=sim_400_leaves['velocity dispersion'], z=sim_400_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 0.57 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_1000_leaves['mass'], y=sim_1000_leaves['velocity dispersion'], z=sim_1000_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.1 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_2200_leaves['mass'], y=sim_2200_leaves['velocity dispersion'], z=sim_2200_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.7 Myr leaves'))
fig.add_trace(go.Scatter3d(x=sim_2800_leaves['mass'], y=sim_2800_leaves['velocity dispersion'], z=sim_2800_leaves['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 2.2 Myr leaves'))
fig.add_trace(go.Surface(x=np.logspace(4, 8, 100), y=np.logspace(0, 2, 100), z=np.ones((100, 100)), 
                         opacity=0.5, name='virial equilibrium'))
fig.update_layout(scene=dict
                  (xaxis=dict(title='mass [M_solar]', type='log'), 
                   yaxis=dict(title='velocity dispersion [km/s]', type='log'), 
                   zaxis=dict(title='virial parameter', type='log'), 
                   aspectmode='cube'))
offline.plot(fig)
# Out:
# 'temp-plot.html'

# %%
fig = go.Figure()
fig.add_trace(go.Scatter3d(x=W43_trunk['mass'], y=W43_trunk['velocity dispersion'], z=W43_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W43 trunk'))
fig.add_trace(go.Scatter3d(x=W51_trunk['mass'], y=W51_trunk['velocity dispersion'], z=W51_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='W51 trunk'))
fig.add_trace(go.Scatter3d(x=M16_trunk['mass'], y=M16_trunk['velocity dispersion'], z=M16_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M16 trunk'))
fig.add_trace(go.Scatter3d(x=M17_trunk['mass'], y=M17_trunk['velocity dispersion'], z=M17_trunk['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='circle'), name='M17 trunk'))
fig.add_trace(go.Scatter3d(x=sim_400_branches['mass'], y=sim_400_branches['velocity dispersion'], z=sim_400_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 0.57 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_1000_branches['mass'], y=sim_1000_branches['velocity dispersion'], z=sim_1000_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.1 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_2200_branches['mass'], y=sim_2200_branches['velocity dispersion'], z=sim_2200_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 1.7 Myr branches'))
fig.add_trace(go.Scatter3d(x=sim_2800_branches['mass'], y=sim_2800_branches['velocity dispersion'], z=sim_2800_branches['virial parameter'],
                            mode='markers', marker=dict(size=3, symbol='x'), name='simlation 2.2 Myr branches'))
fig.add_trace(go.Surface(x=np.logspace(4, 8, 100), y=np.logspace(0, 2, 100), z=np.ones((100, 100)),
                            opacity=0.5, name='virial equilibrium'))
fig.update_layout(scene=dict
                    (xaxis=dict(title='mass [M_solar]', type='log'), 
                     yaxis=dict(title='velocity dispersion [km/s]', type='log'), 
                     zaxis=dict(title='virial parameter', type='log'), 
                     aspectmode='cube'))
offline.plot(fig)
# Out:
# 'temp-plot.html'
