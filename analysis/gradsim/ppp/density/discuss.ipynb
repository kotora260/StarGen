# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
left = ['m400', 'm1000', 'm2200', 'm2800']
myr = [0.5702, 1.104, 1.703, 2.188]

# %%
# plot the number of structures in 3D

plt.plot(left, [7, 31, 25, 22], marker='o', label='leaves')
plt.plot(left, [0, 16, 14, 14], marker='o', label='branches')

plt.title("The number of structures in 3D")
plt.xlabel("time progress")
plt.ylabel("number")
plt.legend()

#plt.savefig("number_3D")

# %%
# make histgram of the size of all structures in 3D

leaf_size_400 = [122.0189165615011, 63.66204342339188, 145.89218284527306, 230.77490740979556, 68.96721370867454, 185.68095998489298, 53.051702852826566]
leaf_size_1000 = [2753.3833780616987, 2103.5000181145733, 1175.0952181901084, 2246.739615817205, 164.46027884376235, 360.75157939922065, 1026.550450202194, 68.96721370867454, 61.00945828075055, 74.27238399395719, 225.4697371245129, 190.98613027017564, 124.67150170414243, 58.35687313810922, 84.8827245645225, 63.66204342339188, 790.4703725071158, 63.66204342339188, 55.704287995467894, 103.4508205630118, 297.08953597582877, 84.8827245645225, 342.18348340073135, 79.57755427923985, 129.97667198942509, 124.67150170414243, 143.23959770263173, 82.23013942188118, 106.10340570565313, 196.2913005554583, 103.4508205630118]
leaf_size_2200 = [4291.882760793669, 3984.182884247275, 167.11286398640368, 53.051702852826566, 400.54035653884057, 183.02837484225165, 488.0756662460044, 90.18789484980516, 228.12232226715423, 111.40857599093579, 334.22572797280736, 129.97667198942509, 76.92496913659852, 58.35687313810922, 66.3146285660332, 124.67150170414243, 631.3152639486361, 700.2824776573107, 90.18789484980516, 262.6059291214915, 90.18789484980516, 793.1229576497572, 119.36633141885977, 135.28184227470774, 55.704287995467894]
leaf_size_2800 = [95.49306513508782, 3652.609741417109, 3408.571908294107, 3177.7970008843113, 71.61979885131586, 2039.8379746911814, 1684.3915655772435, 161.80769370112102, 116.71374627621844, 185.68095998489298, 427.06620796525385, 175.07061941432767, 116.71374627621844, 71.61979885131586, 116.71374627621844, 76.92496913659852, 188.3335451275343, 177.723204556969, 55.704287995467894, 153.84993827319704, 82.23013942188118, 82.23013942188118]

branch_size_400 = []
branch_size_1000 = [143.23959770263173, 79.57755427923985, 135.28184227470774, 68.96721370867454, 1352.8184227470774, 700.2824776573107, 265.2585142641328, 164.46027884376235, 135.28184227470774, 68.96721370867454, 389.93001596827526, 111.40857599093579, 66.3146285660332, 251.9955885509262, 58.35687313810922, 342.18348340073135]
branch_size_2200 = [233.4274925524369, 2042.4905598338228, 2893.970390621689, 2437.7257460873807, 79.57755427923985, 294.43695083318744, 660.4937005176907, 1087.5599084829446, 61.00945828075055, 668.4514559456147, 129.97667198942509, 320.9628022596007, 55.704287995467894, 119.36633141885977]
branch_size_2800 = [63.66204342339188, 270.5636845494155, 2535.87139636511, 55.704287995467894, 1074.296982769738, 2321.0119998111622, 87.53530970716383, 336.8783131154487, 63.66204342339188, 1546.4571381598944, 53.051702852826566, 82.23013942188118, 68.96721370867454, 55.704287995467894]

bins = 12
range = (0, 5000)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8), sharex=True, sharey=True)
axes[0, 0].hist(leaf_size_400, bins=bins, range=range, label='leaves')
axes[0, 0].hist(branch_size_400, bins=bins, range=range, alpha=0.5, label='branches')
axes[0, 1].hist(leaf_size_1000, bins=bins, range=range, label='leaves')
axes[0, 1].hist(branch_size_1000, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 0].hist(leaf_size_2200, bins=bins, range=range, label='leaves')
axes[1, 0].hist(branch_size_2200, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 1].hist(leaf_size_2800, bins=bins, range=range, label='leaves')
axes[1, 1].hist(branch_size_2800, bins=bins, range=range, alpha=0.5, label='branches')

axes[0, 0].set_title('0.57 Myr')
axes[0, 0].set_ylabel('number')
axes[0, 0].legend()
axes[0, 1].set_title('1.1 Myr')
axes[0, 1].legend()
axes[1, 0].set_title('1.7 Myr')
axes[1, 0].set_xlabel('size [pc$^3$]')
axes[1, 0].legend()
axes[1, 1].set_title('2.2 Myr')
axes[1, 1].set_xlabel('size [pc$^3$]')
axes[1, 1].legend()

#fig.savefig('size_hist_3D', bbox_inches='tight')

# %%
# plot average of size

leaf_size_ave = [124.29256096947938, 435.02396339317784, 546.6447461955249, 741.759263524066]
branch_size_ave = [0, 270.89525769224565, 791.7966650784365, 615.3997530927882]

plt.plot(myr, leaf_size_ave, marker='o', label='leaf')
plt.plot(myr, branch_size_ave, marker='o', label='branch')

plt.title('average of size')
plt.xlabel('time [Myr]')
plt.ylabel('size [pc$^3$]')
plt.legend()

#plt.savefig('size_ave', bbox_inches='tight')

# %%
# make histgram of  the mass of all structures in 3D

leaf_mass_400 = [1.3010178610042486e-22, 7.349280448119454e-23, 1.5259775207950354e-22, 2.457167944547061e-22, 6.585329992675497e-23, 2.0861292067299584e-22, 4.834907742007829e-23]
leaf_mass_1000 =[3.770789437368017e-21, 3.0729111283967438e-21, 1.8841650272308137e-21, 3.2708741222406996e-21, 2.6980845323092047e-22, 6.737282168412737e-22, 1.690356600496636e-21, 9.054545367901198e-23, 6.967110112619348e-23, 1.518759028536247e-22, 3.803522541809573e-22, 3.4326205771429945e-22, 1.466336592438763e-22, 1.093196449434016e-22, 1.3230892132731054e-22, 9.042971642939303e-23, 1.299497440014834e-21, 1.117288700060392e-22, 5.844221848475631e-23, 1.6424051351122852e-22, 3.837272811218305e-22, 9.960251997374518e-23, 4.389461016354993e-22, 1.0158658357960873e-22, 1.628119973468295e-22, 1.4460437308954799e-22, 1.7047699860345764e-22, 1.472784204297713e-22, 1.1558848472235827e-22, 2.742229765200393e-22, 1.7479271041696995e-22]
leaf_mass_2200 =[6.783103763911766e-21, 6.456909048614168e-21, 2.6018882765448863e-22, 6.310349627277881e-23, 7.633656180096856e-22, 4.1750551145856423e-22, 1.0768116834997684e-21, 1.729739295233258e-22, 4.91644965343118e-22, 2.146366336043606e-22, 6.68343213269483e-22, 1.6891640670314643e-22, 8.231659056339151e-23, 6.825459990027946e-23, 1.039119546269778e-22, 1.4714520167531358e-22, 1.0988190472610626e-21, 1.1907280172555218e-21, 8.833230413922028e-23, 3.377533793837947e-22, 1.158754634873873e-22, 1.3087728931894275e-21, 1.4682198469796737e-22, 1.8154819449226608e-22, 5.83051458605843e-23]
leaf_mass_2800 = [1.5783964501486281e-22, 6.4685152859205216e-21, 6.183160651772056e-21, 5.885413586713292e-21, 1.1663727780731847e-22, 4.33000618723441e-21, 3.700565226285191e-21, 3.747557482013577e-22, 3.0477617261642704e-22, 6.649700062361731e-22, 9.291768415242991e-22, 2.2471328486174044e-22, 3.132021446480878e-22, 7.414552142595412e-23, 1.3705072672991792e-22, 1.357472802909844e-22, 4.820409899578557e-22, 2.1157797655546234e-22, 7.045066169935487e-23, 2.364534807986208e-22, 1.409299527245162e-22, 9.352941797016529e-23]

branch_mass_400 = []
branch_mass_1000 = [1.8472844075678198e-22, 1.0499489645238898e-22, 1.8996648248385175e-22, 9.691897350179465e-23, 2.0963419097650324e-21, 1.1619372844049019e-21, 3.7440612913048365e-22, 3.229115167608302e-22, 2.694935656257743e-22, 7.667203154678116e-23, 6.143984080196966e-22, 1.9094043643270793e-22, 7.616251420607902e-23, 2.8077203048281985e-22, 6.485397791123785e-23, 4.758953627368551e-22]
branch_mass_2200 = [4.837021724328245e-22, 3.843133727715068e-21, 4.866052443167794e-21, 4.287522538059649e-21, 1.7761921037455955e-22, 5.8938706022364385e-22, 1.362989255515395e-21, 2.162660920995643e-21, 1.0664910472727314e-22, 1.3029086968035467e-21, 3.5840227605925464e-22, 7.858971065313035e-22, 8.094014479323547e-23, 1.620772750630986e-22]
branch_mass_2800 = [8.116573082693578e-23, 5.693655136936277e-22, 4.986869483412415e-21, 8.800153213753015e-23, 2.428637700794396e-21, 4.712188052026358e-21, 2.2690980784769773e-22, 1.0321442428344549e-21, 2.0220802227268155e-22, 3.410262683469903e-21, 7.034509502089702e-23, 1.7632539449104005e-22, 1.65621723485084e-22, 8.314801077130577e-23]

bins = 12
range = (0, 7e-21)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8), sharex=True, sharey=True)
axes[0, 0].hist(leaf_mass_400, bins=bins, range=range, label='leaves')
axes[0, 0].hist(branch_mass_400, bins=bins, range=range, alpha=0.5, label='branches')
axes[0, 1].hist(leaf_mass_1000, bins=bins, range=range, label='leaves')
axes[0, 1].hist(branch_mass_1000, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 0].hist(leaf_mass_2200, bins=bins, range=range, label='leaves')
axes[1, 0].hist(branch_mass_2200, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 1].hist(leaf_mass_2800, bins=bins, range=range, label='leaves')
axes[1, 1].hist(branch_mass_2800, bins=bins, range=range, alpha=0.5, label='branches')

axes[0, 0].set_title('0.57 Myr')
axes[0, 0].set_ylabel('number')
axes[0, 0].legend()
axes[0, 1].set_title('1.1 Myr')
axes[0, 1].legend()
axes[1, 0].set_title('1.7 Myr')
axes[1, 0].set_xlabel('density [g cm$^{-3}$]')
axes[1, 0].legend()
axes[1, 1].set_title('2.2 Myr')
axes[1, 1].set_xlabel('density [g cm$^{-3}$]')
axes[1, 1].legend()

#fig.savefig('mass_hist_3D', bbox_inches='tight')

# %%
# plot average of density

leaf_mass_ave = [1.3210349073366546e-22, 6.449864253793448e-22, 8.98643514975914e-22, 1.4198026394085712e-21]
branch_mass_ave = [0, 4.1133712251362606e-22, 1.4692815666044493e-21, 1.3023709280774517e-21]

fig, ax = plt.subplots()

ax.plot(myr, leaf_mass_ave, marker='o', label='leaf')
ax.plot(myr, branch_mass_ave, marker='o', label='branch')

plt.title('average of mass')
plt.xlabel('time [Myr]')
plt.ylabel('density [g cm$^{-3}$]')
plt.legend()

#plt.savefig('mass_ave', bbox_inches='tight')
