# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ptick

# %%
left = ['m400', 'm1000', 'm2200', 'm2800']
myr = [0.5702, 1.104, 1.703, 2.188]
plt.rcParams["font.size"] = 15

# %%
# plot the number of structures in 2D

plt.plot(left, [3, 3, 4, 2], marker='o', label='leaves')
plt.plot(left, [2, 2, 2, 1], marker='o', label='branches')
plt.yticks(np.arange(0, 6, 1)) 

plt.title("The number of structures in 2D")
plt.xlabel("time progress")
plt.ylabel("number")
plt.legend()

#plt.savefig("number_2D")

# %%
# make histgram the size of all structures in 2D

leaf_size_400 = [126.47076845, 86.2300694, 55.57048917]
leaf_size_1000 = [47.90559411, 136.05188727, 40.24069905]
leaf_size_2200 = [42.15692282, 38.32447529, 84.31384563, 40.24069905]
leaf_size_2800 = [76.64895058, 312.3444736]

branch_size_400 = [1191.89118147, 343.00405383]
branch_size_1000 = [858.46824646, 967.69300103]
branch_size_2200 = [845.05468011, 241.44419432]
branch_size_2800 = [825.89244246]

bins = 12
range = (0, 1200)

fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16, 3), sharex=True, sharey=True)
axes[0].hist(leaf_size_400, bins=bins, range=range, label='leaves')
axes[0].hist(branch_size_400, bins=bins, range=range, alpha=0.5, label='branches')
axes[1].hist(leaf_size_1000, bins=bins, range=range, label='leaves')
axes[1].hist(branch_size_1000, bins=bins, range=range, alpha=0.5, label='branches')
axes[2].hist(leaf_size_2200, bins=bins, range=range, label='leaves')
axes[2].hist(branch_size_2200, bins=bins, range=range, alpha=0.5, label='branches')
axes[3].hist(leaf_size_2800, bins=bins, range=range, label='leaves')
axes[3].hist(branch_size_2800, bins=bins, range=range, alpha=0.5, label='branches')

plt.yticks(np.arange(0, 5, 1)) 

axes[0].set_title('0.57 [Myr]')
axes[0].set_ylabel('number')
axes[0].set_xlabel('size [pc$^2$]')
axes[0].legend()
axes[1].set_title('1.1 [Myr]')
axes[1].set_xlabel('size [pc$^2$]')
axes[1].legend()
axes[2].set_title('1.7 [Myr]')
axes[2].set_xlabel('size [pc$^2$]')
axes[2].legend()
axes[3].set_title('2.2 [Myr]')
axes[3].set_xlabel('size [pc$^2$]')
axes[3].legend()

#fig.savefig('size_hist_2D_slide', bbox_inches='tight')

# %%
# make histgram of the mass of all structures in 2D

leaf_mass_400 = [73370.27119315762, 59195.409926085435, 34242.34182361973]
leaf_mass_1000 = [25696.755629660933, 116010.15909068486, 30320.89549057875]
leaf_mass_2200 = [17681.274058123312, 31640.5122211156, 83040.93054706795, 35963.24932525283]
leaf_mass_2800 = [52118.290098283826, 226889.68263337266]

branch_mass_400 = [575791.3856187873, 202409.55575027614]
branch_mass_1000 = [493971.11368961167, 540569.8987091397]
branch_mass_2200 = [502886.8817423286, 197254.124984529]
branch_mass_2800 = [473164.76796248835]

bins = 12
range = (0, 600000)

fig, axes = plt.subplots(nrows=1, ncols=4, figsize=(16, 3), sharex=True, sharey=True)
axes[0].hist(leaf_mass_400, bins=bins, range=range, label='leaves')
axes[0].hist(branch_mass_400, bins=bins, range=range, alpha=0.5, label='branches')
axes[1].hist(leaf_mass_1000, bins=bins, range=range, label='leaves')
axes[1].hist(branch_mass_1000, bins=bins, range=range, alpha=0.5, label='branches')
axes[2].hist(leaf_mass_2200, bins=bins, range=range, label='leaves')
axes[2].hist(branch_mass_2200, bins=bins, range=range, alpha=0.5, label='branches')
axes[3].hist(leaf_mass_2800, bins=bins, range=range, label='leaves')
axes[3].hist(branch_mass_2800, bins=bins, range=range, alpha=0.5, label='branches')

axes[0].xaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
axes[0].ticklabel_format(style="sci", axis="x", scilimits=(5,5))
axes[1].xaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
axes[1].ticklabel_format(style="sci", axis="x", scilimits=(5,5))
axes[2].xaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
axes[2].ticklabel_format(style="sci", axis="x", scilimits=(5,5))
axes[3].xaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
axes[3].ticklabel_format(style="sci", axis="x", scilimits=(5,5))

plt.yticks(np.arange(0, 5, 1)) 

axes[0].set_title('0.57 [Myr]')
axes[0].set_ylabel('number')
axes[0].set_xlabel('mass [$M_☉$]')
axes[0].legend()
axes[1].set_title('1.1 [Myr]')
axes[1].set_xlabel('mass [$M_☉$]')
axes[1].legend()
axes[2].set_title('1.7 [Myr]')
axes[2].set_xlabel('mass [$M_☉$]')
axes[2].legend()
axes[3].set_title('2.2 [Myr]')
axes[3].set_xlabel('mass [$M_☉$]')
axes[3].legend()

#fig.savefig('mass_hist_2D_slide', bbox_inches='tight')

# %%
# make histgram of virial parameter of all structures in 2D

leaf_alpha_vir_400 = [7.26504057, 6.54455892, 14.58746317]
leaf_alpha_vir_1000 = [5.22251521, 3.27117974, 4.6724522 ]
leaf_alpha_vir_2200 = [6.38235817, 11.29824881, 2.77253725, 3.9029374 ]
leaf_alpha_vir_2800 = [7.88241425, 1.80629364]

branch_alpha_vir_400 = [4.18025159, 4.89245722]
branch_alpha_vir_1000 = [2.60214695, 2.974195]
branch_alpha_vir_2200 = [1.96481491, 2.40191091]
branch_alpha_vir_2800 = [1.79320436]

bins = 12
range = (0, 12)

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 8), sharex=True, sharey=True)
axes[0, 0].hist(leaf_alpha_vir_400, bins=bins, range=range, label='leaves')
axes[0, 0].hist(branch_alpha_vir_400, bins=bins, range=range, alpha=0.5, label='branches')
axes[0, 1].hist(leaf_alpha_vir_1000, bins=bins, range=range, label='leaves')
axes[0, 1].hist(branch_alpha_vir_1000, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 0].hist(leaf_alpha_vir_2200, bins=bins, range=range, label='leaves')
axes[1, 0].hist(branch_alpha_vir_2200, bins=bins, range=range, alpha=0.5, label='branches')
axes[1, 1].hist(leaf_alpha_vir_2800, bins=bins, range=range, label='leaves')
axes[1, 1].hist(branch_alpha_vir_2800, bins=bins, range=range, alpha=0.5, label='branches')

plt.xticks(np.arange(0, 12, 2))

axes[0, 0].set_title('m400')
axes[0, 0].set_ylabel('number')
axes[0, 0].legend()
axes[0, 1].set_title('m1000')
axes[0, 1].legend()
axes[1, 0].set_title('m2200')
axes[1, 0].set_xlabel('alpha_vir')
axes[1, 0].set_ylabel('number')
axes[1, 0].legend()
axes[1, 1].set_title('m2800')
axes[1, 1].set_xlabel('alpha_vir')
axes[1, 1].legend()

#fig.savefig('alpha_gvir_hist_2D')

# %%
# plot the　size of trunk in 2D

trunk_size = [1191.8911814689636, 967.6930010318756, 845.054680109024, 825.8924424648285]

plt.plot(myr, trunk_size, marker="o")

plt.title("size of trunk")
plt.xlabel("time [Myr]")
plt.ylabel('size [pc$^2$]')
plt.tick_params(labelsize=12)

#plt.savefig("trunk_size_2D")

# %%
# plot the mass and virial mass of trunk in 2D

trunk_mass = [575791.3856187873, 540569.8987091397, 502886.8817423286, 473164.76796248835]
#m_vir = [698117.76281392, 466318.23913807, 286584.73610843, 246095.28322144]

fig, ax = plt.subplots()

ax.plot(myr, trunk_mass, marker="o", label='M')
#plt.plot(myr, m_vir, marker="o", label='Mvir')

ax.yaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
ax.ticklabel_format(style="sci", axis="y", scilimits=(5,5))

plt.title("mass of trunk")
plt.xlabel("time [Myr]")
plt.ylabel('mass [$M_☉$]')
plt.tick_params(labelsize=12)
#plt.legend()

#plt.savefig("trunk_mass_2D")

# %%
# plot velocity dispersion of trunk

dv = [14.17061801, 12.20085876, 9.8943877, 9.22155945]

plt.plot(myr, dv, marker='o')

plt.title('velocity dispersion of trunk')
plt.xlabel('time [Myr]')
plt.ylabel('velocity dispersion [km s$^{-1}$]')
plt.tick_params(labelsize=12)

#plt.savefig('dv_trunk_2D')

# %%
# plot virial parameter of trunk in 2D

alpha_gvir = [4.18025159, 2.974195, 1.96481491, 1.79320436]

plt.plot(myr, alpha_gvir, marker="o")

plt.title("virial parameter of trunk")
plt.xlabel("time [Myr]")
plt.ylabel("virial parameter")
plt.tick_params(labelsize=12)

#plt.savefig("alpha_gvir_trunk_2D")

# %%
# plot average of size

leaf_size_ave = [89.4237756729126, 74.73272681236267, 51.258985698223114, 194.4967120885849]
branch_size_ave = [767.447617650032, 913.0806237459183, 543.249437212944, 825.8924424648285]

plt.plot(myr, leaf_size_ave, marker='o', label='leaf')
plt.plot(myr, branch_size_ave, marker='o', label='branch')

plt.title('average of size')
plt.xlabel('time [Myr]')
plt.ylabel('size [$pc^2$]')
plt.tick_params(labelsize=12)
plt.legend()

# %%
# plot average of mass

leaf_mass_ave = [55602.6743142876, 57342.603403641515, 42081.491537889924, 139503.98636582826]
branch_mass_ave = [389100.4706845317, 517270.50619937567, 350070.50336342875, 473164.76796248835]

plt.plot(myr, leaf_mass_ave, marker='o', label='leaf')
plt.plot(myr, branch_mass_ave, marker='o', label='branch')

plt.title('average of mass')
plt.xlabel('time [Myr]')
plt.ylabel('mass [$M_\odot$]')
plt.tick_params(labelsize=12)
plt.legend()
# Out:
# <>:11: SyntaxWarning: invalid escape sequence '\o'
# <>:11: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\kotor\AppData\Local\Temp\ipykernel_19116\2213007061.py:11: SyntaxWarning: invalid escape sequence '\o'
#   plt.ylabel('mass [$M_\odot$]')

# %%
# plot average of vir

leaf_vir_ave = [9.465687554475412, 4.388715717133223, 6.089020409120821, 4.8443539438157]
branch_vir_ave = [4.536354402675039, 2.7881709753394004, 2.1833629062507796, 1.793204358944282]

plt.plot(myr, leaf_vir_ave, marker='o', label='leaf')
plt.plot(myr, branch_vir_ave, marker='o', label='branch')

plt.title('average of vir')
plt.xlabel('time [Myr]')
plt.ylabel('virial parameter]')
plt.tick_params(labelsize=12)
plt.legend()

# %%
# plot average size of inner structure

inner_size_ave = [152.81884521218444, 270.666606724272, 89.29602742257849, 194.4967120885849]

plt.plot(myr, inner_size_ave, marker='o')

plt.title('average size of inner structure')
plt.xlabel('time [Myr]')
plt.ylabel('size [pc$^2$]')
plt.tick_params(labelsize=12)

plt.savefig('inner_size', bbox_inches='tight')

# %%
# plot average mass of inner structure

inner_mass_ave = [92304.39467328473, 166499.73097513407, 73116.01822721775, 139503.98636582826]

fig, ax = plt.subplots()
ax.plot(myr, inner_mass_ave, marker='o')

ax.yaxis.set_major_formatter(ptick.ScalarFormatter(useMathText=True))
ax.ticklabel_format(style="sci", axis="y", scilimits=(5,5))

plt.title('average mass of inner structure')
plt.xlabel('time [Myr]')
plt.ylabel('mass [$M_\odot$]')
plt.tick_params(labelsize=12)

plt.savefig('inner_mass', bbox_inches='tight')
# Out:
# <>:13: SyntaxWarning: invalid escape sequence '\o'
# <>:13: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\kotor\AppData\Local\Temp\ipykernel_19116\2763677245.py:13: SyntaxWarning: invalid escape sequence '\o'
#   plt.ylabel('mass [$M_\odot$]')

# %%
# plot average vir of inner structure

inner_vir_ave = [8.32237997085656, 3.9420735253499175, 5.351598509296657, 4.8443539438157]

plt.plot(myr, inner_vir_ave, marker='o')

plt.title('average virial parameter of inner structure')
plt.xlabel('time [Myr]')
plt.ylabel('virial paremeter')
plt.tick_params(labelsize=12)

plt.savefig('inner_vir', bbox_inches='tight')
